# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = "/content/drive/MyDrive/Data CodingDojo/linear.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#             x           y
# 0    0.000000  -51.000000
# 1   25.000000  -12.000000
# 2  117.583220  134.907414
# 3  108.922466  134.085180
# 4   69.887445         NaN

# %% [markdown]
# # Convertir los dataframe de pandas a array de NumPy
#
# Si bien los dataframe de pandas son entradas aceptables para una gran variedad de bibliotecas, hay ocasiones donde necesitan tener sus datos en un array de NumPy, algunos paquetes estadisticos prefieren arrays de NumPy
#
# Se puede mediante
#
# df.to_numpy()
#
# df.values

# %%
#Metodo 1
df.to_numpy()
# Out:
# array([[  0.        , -51.        ],
#        [ 25.        , -12.        ],
#        [117.5832198 , 134.9074137 ],
#        [108.9224662 , 134.0851795 ],
#        [ 69.88744536,          nan],
#        [ 96.83998269, 114.5306376 ],
#        [ 51.77594025,  31.37643731],
#        [ 35.01673734,   8.76463417],
#        [ 79.45764646,  73.28534128],
#        [ 45.3449093 ,  18.85986466],
#        [ 77.76713229,  72.9466086 ],
#        [ 55.85663802,  28.63728633],
#        [ 51.8290553 ,  27.18413784],
#        [ 36.07902502,  15.46895475],
#        [ 80.63255196,  77.25552457],
#        [124.4126644 , 147.817536  ],
#        [ 38.88238694,  29.62914801],
#        [ 85.24501874,  92.31571653],
#        [105.4849878 , 111.063745  ],
#        [ 36.82741469,   2.79748519],
#        [ 98.61682009,  98.22796195],
#        [102.1309415 , 117.0827211 ],
#        [101.9740862 , 111.1555591 ],
#        [122.5816416 , 147.0235042 ],
#        [ 96.36839009,  99.62870641],
# ...

# %%
#Metodo 2
df.values
# Out:
# array([[  0.        , -51.        ],
#        [ 25.        , -12.        ],
#        [117.5832198 , 134.9074137 ],
#        [108.9224662 , 134.0851795 ],
#        [ 69.88744536,          nan],
#        [ 96.83998269, 114.5306376 ],
#        [ 51.77594025,  31.37643731],
#        [ 35.01673734,   8.76463417],
#        [ 79.45764646,  73.28534128],
#        [ 45.3449093 ,  18.85986466],
#        [ 77.76713229,  72.9466086 ],
#        [ 55.85663802,  28.63728633],
#        [ 51.8290553 ,  27.18413784],
#        [ 36.07902502,  15.46895475],
#        [ 80.63255196,  77.25552457],
#        [124.4126644 , 147.817536  ],
#        [ 38.88238694,  29.62914801],
#        [ 85.24501874,  92.31571653],
#        [105.4849878 , 111.063745  ],
#        [ 36.82741469,   2.79748519],
#        [ 98.61682009,  98.22796195],
#        [102.1309415 , 117.0827211 ],
#        [101.9740862 , 111.1555591 ],
#        [122.5816416 , 147.0235042 ],
#        [ 96.36839009,  99.62870641],
# ...

# %% [markdown]
# # Convertir los dataframe de pandas a diccionarios
#
# esta seccion es para mostrarles que pandas les permite convertir sus dataframes en una variedad de diferentes objetos

# %%
df.to_dict();

# %%
df.y
# Out:
# 0      -51.000000
# 1      -12.000000
# 2      134.907414
# 3      134.085180
# 4             NaN
#           ...
# 97     133.922297
# 98     126.827116
# 99      50.257797
# 100    144.754676
# 101    120.697309
# Name: y, Length: 102, dtype: float64

# %%
df.to_csv("testasdasd")
