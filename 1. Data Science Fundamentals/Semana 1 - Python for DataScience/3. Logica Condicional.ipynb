# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
1 + 1 == (True + True)
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
