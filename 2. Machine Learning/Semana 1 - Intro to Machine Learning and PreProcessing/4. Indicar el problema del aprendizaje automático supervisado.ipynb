# %%
import pandas as pd

from google.colab import drive
drive.mount ("/content/drive")
# Out:
# Mounted at /content/drive

# %%
filename = "/content/drive/MyDrive/Data CodingDojo/insurance.csv"
df = pd.read_csv(filename)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# #### El objetivo de los problemas del aprendizaje supervisado es poder hacer predicciones basandose en el conjunto de datos que ustedes han proporcionado. Para poder hacer predicciones en datos futuros desconocidos, primero nuestra computadora tiene que "aprender" de casos pasados donde la respuesta ya se sabe.

# %% [markdown]
# ### Ejemplo
#
# a continuacion se muestran los gastos medicos de varios pacientes.

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# # Ordenar los datos en una **matriz de caracteristicas** y un **vector objetivo**
#
# estos son terminos clave al momento de formatear los datos  para el aprendizaje automatico **SUPERVISADO**

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# **Matriz de caracteristicas**: cuadricvula de dos dimensiones de datos donde las filas representan las muestras y las columnas representan las caracteristicas.
#
#
# **Vector objetivo**: es unidimensional y es la columna donde desean predecir.

# %%
# Se asigna la columna objetivo a  -y-
y = df["charges"]

# Asignen las caracteristicas a X (en este caso, incluiremos todas las columnas excepto la de objetivo)
X = df.drop(columns = "charges")

# %%
# Al comprobar el tipo de objeto, se aprecia que es una serie:
type(y)
# Out:
# pandas.core.series.Series

# %%
y[0:5]
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
# Tambien se aprecia que X es un DataFrame
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    age     sex     bmi  children smoker     region
# 0   19  female  27.900         0    yes  southwest
# 1   18    male  33.770         1     no  southeast
# 2   28    male  33.000         3     no  southeast
# 3   33    male  22.705         0     no  northwest
# 4   32    male  28.880         0     no  northwest

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)
