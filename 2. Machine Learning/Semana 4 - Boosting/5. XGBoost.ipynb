# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# #XGBoost
#
# Significa potenciacion del gradiente extremo, es una aplicacion del algoritmo de potenciacion del gradiente. Esta disenado para la velocidad, memoria eficiente y alto rendimiento.
#
# "Es una biblioteca optimizada de potenciacion de la gradiente disenada para ser altamente eficiente, flexible y portatil. Implementa los algoritmos de aprendizaje automatico bajo el marco de la potenciacion del gradiente. XGBoost proporciona un boosting de arbol paralelo (Tambien conocido como GBDT, GBM) que resuelve numerosos problemas de ciencias de datos de manera rapida y exacta. El mismo codigo se ejecuta en los principales entornos distribuidos (Hadoop, SGE, MPI) y puede resolver problemas mas alla de mil millones de ejemplos"

# %%
from google.colab import drive
drive.mount ("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBrE

# %%
df = pd.read_csv("/content/drive/MyDrive/Data CodingDojo/wisconsinBreastCancer.csv", index_col ="id")
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
# Drop unnecessary column
df.drop(columns = 'Unnamed: 32', inplace = True)
# Binarize target column
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})
# Save X data
X = df.drop(columns = 'diagnosis')
# Encode our target
y = df['diagnosis']

# %% [markdown]
# train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=3)

# %% [markdown]
# aplicacion de XGBoost

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier()

# %% [markdown]
# Evaluacion de modelo

# %%
print('Training accuracy:', xgb.score(X_train, y_train))
print('Testing accuracy:', xgb.score(X_test, y_test))
# Out:
# Training accuracy: 1.0
# Testing accuracy: 0.958041958041958
