# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Los bosques aleatorios ofrecen una variacion leve en los bagged trees. La diferencia es que cuando se crea cada arbol, cada vez que una difivsion se considera, se elige una muestra aleatoria de caracteristicas m como candidatos de divison del conjunto completo de las caracteristicas p. Se le permite a la division usar una de aquellas caracteristicas m. Esto sucede para cada arbol en cada una division.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)
